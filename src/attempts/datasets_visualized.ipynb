# %%
from utilities import plot_fd_and_original, plot_fd_and_speeds
import logging
logging.getLogger('tensorflow').setLevel(logging.WARNING)

# %%
base_path = "../data/dataset_"
plot_fd_and_original(base_path+"corridor_30", plot_title="corridor_30", verbose=0)
plot_fd_and_original(base_path+"corridor_85", plot_title="corridor_85", verbose=0)
plot_fd_and_original(base_path+"corridor_140", plot_title="corridor_140", verbose=0)
plot_fd_and_original(base_path+"bottleneck_070", plot_title="bottleneck_070", verbose=0)
plot_fd_and_original(base_path+"bottleneck_120", plot_title="bottleneck_120", verbose=0)
plot_fd_and_original(base_path+"bottleneck_180", plot_title="bottleneck_180", verbose=0)

# %%
plot_fd_and_speeds(base_path+"corridor_30", plot_title="corridor_30", nn_epochs=1000, verbose=0)
plot_fd_and_speeds(base_path+"corridor_85", plot_title="corridor_85", nn_epochs=1000, verbose=0)
plot_fd_and_speeds(base_path+"corridor_140", plot_title="corridor_140", nn_epochs=1000, verbose=0)
plot_fd_and_speeds(base_path+"bottleneck_070", plot_title="bottleneck_070", nn_epochs=1000, verbose=0)
plot_fd_and_speeds(base_path+"bottleneck_120", plot_title="bottleneck_120", nn_epochs=1000, verbose=0)
plot_fd_and_speeds(base_path+"bottleneck_180", plot_title="bottleneck_180", nn_epochs=1000, verbose=0)
# Out:
# Training the NN model..
# Training the FD model..
# D:\UniPi\erasmus\courses\MLCS\MLCMS-project\src\utilities.py:144: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Training the NN model..
# Training the FD model..
# D:\UniPi\erasmus\courses\MLCS\MLCMS-project\src\utilities.py:144: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Training the NN model..
# Training the FD model..
# D:\UniPi\erasmus\courses\MLCS\MLCMS-project\src\utilities.py:144: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Training the NN model..
# Training the FD model..
# ...
