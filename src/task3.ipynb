# %% [markdown]
# # VADERE validity check
#
# Check the validity of the implemented neural networks through some self produced scenarios

# %%
from data_preprocessing_vadere import create_complete_dataset_vadere, get_time_delta
from utilities import plot_fd_and_original, plot_fd_and_speeds
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## CORRIDOR SCENARIO

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# create the final corridor file, ready for training
base_path = "../vadere-projects/output/corridor_vadere_final/"
dataset_save_path = "../data/vadere_corridor_100"
time_step = get_time_delta(base_path)  # dependent on the simulation, pay attention!
knn_file = np.loadtxt(base_path + "out.txt", skiprows=1)  # get the file containing knns, remove header line
knn_df = create_complete_dataset_vadere(knn_file=knn_file, time_step=time_step, dataset_save_path=dataset_save_path)

# %%
# plot observations and fd model predicted on them
plot_fd_and_original(data_path=dataset_save_path)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 1s 867us/step - loss: 0.6748
# Epoch 2/50
# 31/31 [==============================] - 0s 861us/step - loss: 0.5115
# Epoch 3/50
# 31/31 [==============================] - 0s 837us/step - loss: 0.3899
# Epoch 4/50
# 31/31 [==============================] - 0s 819us/step - loss: 0.2856
# Epoch 5/50
# 31/31 [==============================] - 0s 780us/step - loss: 0.2125
# Epoch 6/50
# 31/31 [==============================] - 0s 800us/step - loss: 0.1649
# Epoch 7/50
# 31/31 [==============================] - 0s 794us/step - loss: 0.1407
# Epoch 8/50
# 31/31 [==============================] - 0s 817us/step - loss: 0.1306
# Epoch 9/50
# 31/31 [==============================] - 0s 800us/step - loss: 0.1280
# Epoch 10/50
# 31/31 [==============================] - 0s 858us/step - loss: 0.1271
# Epoch 11/50
# 31/31 [==============================] - 0s 782us/step - loss: 0.1269
# Epoch 12/50
# ...

# %%
# plot nn predictions and fd model predicted on them
plot_fd_and_speeds(data_path=dataset_save_path, nn_epochs=10000, hidden_dims=(3,3,3,), hidden_activation_func='tanh')
# Out:
# Training the NN model..
# Epoch 1/10000
# 31/31 [==============================] - 0s 833us/step - loss: 0.5644
# Epoch 2/10000
# 31/31 [==============================] - 0s 883us/step - loss: 0.2427
# Epoch 3/10000
# 31/31 [==============================] - 0s 826us/step - loss: 0.2002
# Epoch 4/10000
# 31/31 [==============================] - 0s 808us/step - loss: 0.1806
# Epoch 5/10000
# 31/31 [==============================] - 0s 806us/step - loss: 0.1684
# Epoch 6/10000
# 31/31 [==============================] - 0s 840us/step - loss: 0.1603
# Epoch 7/10000
# 31/31 [==============================] - 0s 861us/step - loss: 0.1547
# Epoch 8/10000
# 31/31 [==============================] - 0s 747us/step - loss: 0.1506
# Epoch 9/10000
# 31/31 [==============================] - 0s 962us/step - loss: 0.1472
# Epoch 10/10000
# 31/31 [==============================] - 0s 819us/step - loss: 0.1448
# Epoch 11/10000
# 31/31 [==============================] - 0s 812us/step - loss: 0.1428
# ...

# %% [markdown]
# ## BOTTLENECK SCENARIO

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# create the final bottleneck file, ready for training
base_path = "../vadere-projects/output/bottleneck_vadere_final/"
dataset_save_path = "../data/vadere_bottleneck_100_90"
time_step = get_time_delta(base_path)  # dependent on the simulation, pay attention!
knn_file = np.loadtxt(base_path + "out.txt", skiprows=1)  # get the file containing knns, remove header line
knn_df = create_complete_dataset_vadere(knn_file, time_step, dataset_save_path=dataset_save_path)

# %%
# plot observations and fd model predicted on them
plot_fd_and_original(data_path=dataset_save_path)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.1363
# Epoch 2/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.1363
# Epoch 3/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.1362
# Epoch 4/50
# 23/23 [==============================] - 0s 954us/step - loss: 0.1362
# Epoch 5/50
# 23/23 [==============================] - 0s 909us/step - loss: 0.1362
# Epoch 6/50
# 23/23 [==============================] - 0s 954us/step - loss: 0.1362
# Epoch 7/50
# 23/23 [==============================] - 0s 864us/step - loss: 0.1361
# Epoch 8/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.1361
# Epoch 9/50
# 23/23 [==============================] - 0s 909us/step - loss: 0.1360
# Epoch 10/50
# 23/23 [==============================] - 0s 954us/step - loss: 0.1361
# Epoch 11/50
# 23/23 [==============================] - 0s 818us/step - loss: 0.1360
# Epoch 12/50
# ...

# %%
# plot nn predictions and fd model predicted on them
plot_fd_and_speeds(data_path=dataset_save_path, nn_epochs=10000, hidden_dims=(3,3,), hidden_activation_func='tanh')
# Out:
# Training the NN model..
# Epoch 1/10000
# 23/23 [==============================] - 0s 864us/step - loss: 0.6992
# Epoch 2/10000
# 23/23 [==============================] - 0s 864us/step - loss: 0.3246
# Epoch 3/10000
# 23/23 [==============================] - 0s 807us/step - loss: 0.2499
# Epoch 4/10000
# 23/23 [==============================] - 0s 759us/step - loss: 0.2159
# Epoch 5/10000
# 23/23 [==============================] - 0s 866us/step - loss: 0.1961
# Epoch 6/10000
# 23/23 [==============================] - 0s 931us/step - loss: 0.1832
# Epoch 7/10000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.1743
# Epoch 8/10000
# 23/23 [==============================] - 0s 864us/step - loss: 0.1680
# Epoch 9/10000
# 23/23 [==============================] - 0s 818us/step - loss: 0.1630
# Epoch 10/10000
# 23/23 [==============================] - 0s 867us/step - loss: 0.1593
# Epoch 11/10000
# 23/23 [==============================] - 0s 968us/step - loss: 0.1564
# ...
